# %%
import pandas as pd

# %%
df = pd.read_csv('./keypoint.csv', header=None)
df.head()
# Out:
#    0    1    2         3         4         5         6         7         8   \
# 0   0  0.0  0.0  0.200787 -0.051181  0.366142 -0.181102  0.484252 -0.307087
# 1   0  0.0  0.0  0.206349 -0.043651  0.376984 -0.162698  0.507937 -0.273810
# 2   0  0.0  0.0  0.202381 -0.043651  0.373016 -0.162698  0.500000 -0.277778
# 3   0  0.0  0.0  0.207171 -0.039841  0.382470 -0.159363  0.509960 -0.274900
# 4   0  0.0  0.0  0.206349 -0.039683  0.380952 -0.162698  0.507937 -0.281746
#
#          9   ...        33        34        35        36        37        38  \
# 0  0.594488  ...  0.039370 -0.976378 -0.074803 -0.429134 -0.145669 -0.578740
# 1  0.615079  ...  0.047619 -0.980159 -0.079365 -0.428571 -0.142857 -0.583333
# 2  0.607143  ...  0.039683 -0.980159 -0.083333 -0.428571 -0.146825 -0.579365
# 3  0.617530  ...  0.051793 -0.980080 -0.079681 -0.426295 -0.143426 -0.581673
# 4  0.615079  ...  0.051587 -0.980159 -0.079365 -0.428571 -0.142857 -0.583333
#
#          39        40        41        42
# ...

# %%
print(df.shape)
# Out:
# (3431, 43)

# %%
df = df[df[0] != 2]
df = df[df[0] != 3]

# %%
df.to_csv('./data.csv', header=None, index=None)
